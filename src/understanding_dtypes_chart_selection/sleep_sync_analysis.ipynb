# %%
from IPython.display import Image, display
display(Image(filename="sleep_sync_logo.png"))

# %% [markdown]
# # SleepSync Visualization Exercise
#
# You are a data analyst at **SleepSync**, a health technology company that helps users improve sleep, recovery, and daytime performance. The leadership team wants a small set of polished visualizations they can use to better understand how sleep, stress, activity, and related behaviors may connect to performance and sleep risk.
#
# Use this color palette consistently across your charts:
# - Deep navy: `#1D3557`
# - Teal: `#457B9D`
# - Light aqua: `#A8DADC`
# - Soft background: `#F1FAEE`
# - Accent coral: `#E76F51`
#
# As you work, keep these questions in mind:
# - Which factors seem most connected to cognitive performance?
# - How do sleep duration and sleep quality differ across important groups?
# - What behaviors or conditions seem associated with higher sleep disorder risk?
# - Are there any patterns that could help the company make recommendations to users?
#
# Create **4 to 5 stakeholder-ready visualizations** using this dataset. Each chart should:
# - answer a clear real-world question
# - use an appropriate chart type
# - have a polished, professional appearance
# - include a strong title, clear labels, and intentional color choices
# - be followed by a short interpretation explaining the takeaway
#
# Treat every chart as if it may appear in a real internal report or presentation.
